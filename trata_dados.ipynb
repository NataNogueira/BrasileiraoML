# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Baixa dados da Web para análise

# %%
dados = requests.get("https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol_de_2024_-_S%C3%A9rie_A")
tabelas = pd.read_html(dados.text)
tabela_classificacao = tabelas[6] # Tabela de classificação geral do brasileirão
tabela_confrontos = tabelas[7] # Tabela de confrontos a serem jogados no brasileirão
# Out:
# C:\Users\natan\AppData\Local\Temp\ipykernel_13216\3144841166.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabelas = pd.read_html(dados.text)

# %% [markdown]
# ### Trata dados da Web

# %%
nomes_times = list(tabela_confrontos['Casa \ Fora'])
tabela_confrontos_tratada = pd.DataFrame(tabela_confrontos.iloc[:, 1:].values, columns=nomes_times)
tabela_confrontos_tratada.index = nomes_times
tabela_confrontos_tratada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\natan\AppData\Local\Temp\ipykernel_13216\3134443581.py:1: SyntaxWarning: invalid escape sequence '\ '
#   nomes_times = list(tabela_confrontos['Casa \ Fora'])
#                      Athletico Paranaense Atlético Goianiense  \
# Athletico Paranaense                    —                 NaN
# Atlético Goianiense                   1–2                   —
# Atlético Mineiro                      NaN                 1–1
# Bahia                                 NaN                 NaN
# Botafogo                              1–1                 1–0
# Corinthians                           5–2                 3–0
# Criciúma                              0–0                 2–0
# Cruzeiro                              2–0                 3–1
# Cuiabá                                1–2                 0–0
# Flamengo                              1–0                 2–0
# ...

# %%
tabela_confrontos_tratada.columns
# Out:
# Index(['Athletico Paranaense', 'Atlético Goianiense', 'Atlético Mineiro',
#        'Bahia', 'Botafogo', 'Corinthians', 'Criciúma', 'Cruzeiro', 'Cuiabá',
#        'Flamengo', 'Fluminense', 'Fortaleza', 'Grêmio', 'Internacional',
#        'Juventude', 'Palmeiras', 'Red Bull Bragantino', 'São Paulo',
#        'Vasco da Gama', 'Vitória'],
#       dtype='object')
