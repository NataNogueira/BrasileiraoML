# %%
# Importa as bibliotecas que serão utilizadas

import pandas as pd
import pickle

# %%
# Carregando os dados do arquivo .json
with open('dados.pkl', 'rb') as f:
    dados = pickle.load(f)
    
tabelas = pd.read_html(dados.text)
# Out:
# C:\Users\natan\AppData\Local\Temp\ipykernel_19108\314473900.py:5: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabelas = pd.read_html(dados.text)

# %%
classificacao_SA = tabelas[6]
classificacao_SA
# Out:
#     Pos             Equipevde  Pts   J   V   E   D  GP  GC   SG  \
# 0     1              Botafogo   56  27  17   5   5  46  25  +21
# 1     2             Fortaleza   52  27  15   7   5  36  26  +10
# 2     3             Palmeiras   50  26  15   5   6  43  19  +24
# 3     4              Flamengo   45  25  13   6   6  40  29  +11
# 4     5             São Paulo   44  26  13   5   8  34  26   +8
# 5     6                 Bahia   42  27  12   6   9  38  31   +7
# 6     7              Cruzeiro   41  26  12   5   9  34  27   +7
# 7     8         Internacional   38  24  10   8   6  27  20   +7
# 8     9         Vasco da Gama   35  25  10   5  10  30  35   −5
# 9    10      Atlético Mineiro   33  24   8   9   7  32  36   −4
# 10   11             Juventude   32  27   8   8  11  31  37   −6
# 11   12   Red Bull Bragantino   31  25   8   7  10  31  32   −1
# 12   13  Athletico Paranaense   30  24   8   6  10  27  29   −2
# 13   14                Grêmio   28  24   8   4  12  25  30   −5
# ...

# %%
confrontos_SA = tabelas[7]
confrontos_SA
# Out:
#              Casa \ Fora  ATP  ATG  ATM  BAH  BOT  COR  CRI  CRU  CUI  ...  \
# 0   Athletico Paranaense    —  NaN  NaN  1–3  NaN  1–1  3–1  NaN  4–0  ...
# 1    Atlético Goianiense  1–2    —  NaN  1–1  1–4  2–2  1–2  0–1  NaN  ...
# 2       Atlético Mineiro  NaN  1–1    —  1–1    a  2–1  1–1  3–0  1–1  ...
# 3                  Bahia  NaN  NaN  3–0    —  0–0  0–1  NaN  4–1  1–2  ...
# 4               Botafogo  1–1  1–0  3–0  1–2    —  2–1  NaN  0–3  NaN  ...
# 5            Corinthians    a  3–0  0–0    a  0–1    —  2–1    a  1–1  ...
# 6               Criciúma  NaN  NaN  2–1  2–2  2–1  NaN    —  1–0  2–5  ...
# 7               Cruzeiro  2–0  3–1  0–0  NaN  3–2  3–0  NaN    —  2–1  ...
# 8                 Cuiabá  1–2  0–0  0–3  NaN  1–2  NaN  2–1  NaN    —  ...
# 9               Flamengo  NaN  2–0    a  2–1  0–2  2–0  2–1  2–1  1–1  ...
# 10            Fluminense    a  1–2  2–2  1–0  0–1  0–0  NaN    a  NaN  ...
# ...
